# %%
y= 21
type(y)
# Out:
# int

# %%
y=21.1
type(y)

disable = True # boolean
print(disable)
print('The type of x:', type(disable))
# Out:
# float

# %%
name = 'Kamran' # string
print(name)
print('The type of x:', type(name))
# Out:
# Kamran
# The type of x: <class 'str'>

# %%
y= true   # if we write true in small keyword instead of True , it gives an error 
type(y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 y=true
#       2 type(y)
#
# NameError: name 'true' is not defined

# %%
y = True
type(y)
# Out:
# bool

# %%
z = [1 ,2,3,4]
type(y)
# Out:
# tuple

# %%
y = (1 ,3,4,6)
type(y)
# Out:
# tuple

# %%
print("the type of y is :" , type(y) , "and the type of z is :" , type(z))
# Out:
# the type of y is : <class 'tuple'> and the type of z is : <class 'list'>

# %%
value = 3 + 2j
print(value)
print('The type of x:', type(value))
# Out:
# (3+2j)
# The type of x: <class 'complex'>

# %%
fname = "saif"
lname = "haider"
#space = " "
print(fname+lname , sep=" ")    # sep doesnot work here , because both fname and lnam form a single value
# Out:
# saifhaider

# %%
print(fname + " " + lname)
# Out:
# saif haider
