# %%
import random

guess=random.randint(1,100)   # this part of guessing a numbe is outside the loop , because we guess a number 1 time 
while True:

    try:
        choice =int(input("Guess a number between 1 and 100: " ))    # we write this code inside the try block , bcz there may be a user enter
                                                                       # other non valid character and in this way it generates error
                                                                       # to handle this error we use try except method 
        if(choice > guess ):
            print("Too High!")

        elif(choice == guess):
            print("you guessing the right number")            #  we use   , if , elif aor else inside the try block , because  , let assume if we 
            break                                             #write if , slif ,else outside block and user type  any non valid character the except statement
                              # execute and after this if , elif , else want to execute , you see if except statement executer the choice variable doesnot assign 
                            # a value , and dont use it below on id else stament and it cause the UnboundLocalError / NameError
 
        else(choice<guess):
             print("Too Low")
          
    except ValueError:
        print("Please Enter a Valid Character")
     
  #  guess=random.randint(1,100)                       # if i write this line inside the loop , it will guessa random number everytime
